# %%
# standing data tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# sklearn
from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
# persistence
from sklearn.externals import joblib

from TDPPredictor import *

# %matplotlib inline

# %%
Tag='Results'
outdir='fig/'+Tag
import os
os.system('mkdir -p '+outdir)
#Load the dataset
data=pd.read_csv('../data/round2/batch2_all_viable_merged_v2.csv')
setup_df(data)                 
data.info()
# Out:
# before conversion: 28401
# after conversion: 473.35
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB

# %%
#filter dataset
Vmin=1.
Vmax=2000.
anafilter=(data['Vmes']>Vmin)&(data['Vmes']<Vmax)&(data['Watertight']==True)
sd=data[anafilter]

# cut numbers
ndata=len(data)
nselected=len(sd)
ntrain=np.int(nselected*0.6)
nval=np.int(nselected*0.3)
print 'total input:', ndata, 'total selected:', nselected, 'selection efficiency:', np.divide(nselected,np.float(ndata))
# test first on the training set
sd_test_train = sd.head(ntrain+nval)
sd_train = sd_test_train.head(ntrain)
sd_test = sd_test_train.tail(nval)
print 'train on:',len(sd_train), 'testing on:',len(sd_test)
# Out:
# total input: 3050 total selected: 3038 selection efficiency: 0.99606557377
# train on: 1822 testing on: 911

# %%
sd_train[['t','Vfil','Vsup','sumV','Vmes','Vbb','Vch','Sa','Z','rSaVmes','rVbbVmes','rVchVmes','Vangover']].corr()
# Out:
#                  t      Vfil      Vsup      sumV      Vmes       Vbb  \
# t         1.000000  0.731170  0.757996  0.985809  0.696076  0.652653
# Vfil      0.731170  1.000000  0.113160  0.830461  0.962030  0.684058
# Vsup      0.757996  0.113160  1.000000  0.647473  0.100064  0.263596
# sumV      0.985809  0.830461  0.647473  1.000000  0.793995  0.672475
# Vmes      0.696076  0.962030  0.100064  0.793995  1.000000  0.696310
# Vbb       0.652653  0.684058  0.263596  0.672475  0.696310  1.000000
# Vch       0.666812  0.683538  0.279585  0.681041  0.683988  0.918530
# Sa        0.559169  0.600305  0.191505  0.567816  0.599424  0.792680
# Z         0.401319  0.450621  0.117129  0.411304  0.458004  0.594044
# rSaVmes  -0.185031 -0.269297 -0.018245 -0.216784 -0.270555 -0.123221
# rVbbVmes  0.007033 -0.080810  0.072667 -0.021240 -0.083200  0.268548
# rVchVmes  0.030843 -0.085153  0.101885 -0.008189 -0.090378  0.301817
# Vangover  0.462097  0.264528  0.392042  0.422706  0.265489  0.530236
#
#                Vch        Sa         Z   rSaVmes  rVbbVmes  rVchVmes  Vangover
# t         0.666812  0.559169  0.401319 -0.185031  0.007033  0.030843  0.462097
# Vfil      0.683538  0.600305  0.450621 -0.269297 -0.080810 -0.085153  0.264528
# Vsup      0.279585  0.191505  0.117129 -0.018245  0.072667  0.101885  0.392042
# sumV      0.681041  0.567816  0.411304 -0.216784 -0.021240 -0.008189  0.422706
# Vmes      0.683988  0.599424  0.458004 -0.270555 -0.083200 -0.090378  0.265489
# Vbb       0.918530  0.792680  0.594044 -0.123221  0.268548  0.301817  0.530236
# Vch       1.000000  0.863465  0.544688 -0.114844  0.177089  0.283573  0.536702
# Sa        0.863465  1.000000  0.504484 -0.031730  0.081687  0.187540  0.502332
# Z         0.544688  0.504484  1.000000 -0.179573  0.157062  0.167578  0.402033
# rSaVmes  -0.114844 -0.031730 -0.179573  1.000000  0.441234  0.557743 -0.013461
# rVbbVmes  0.177089  0.081687  0.157062  0.441234  1.000000  0.871745  0.126944
# rVchVmes  0.283573  0.187540  0.167578  0.557743  0.871745  1.000000  0.186679
# Vangover  0.536702  0.502332  0.402033 -0.013461  0.126944  0.186679  1.000000

# %% [markdown]
# ## Train

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
axes.scatter(sd_train.Vmes,sd_train.t/60, color='red',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
plt.xlabel('Extracted Volume (cm^3)')
plt.ylabel('Build Time (hours)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('Build Time (hours)', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t.png')

# %% [markdown]
# ## Overhang

# %%
labels=(sd.Vsup<0.1)
len(labels)
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
h1=plt.hist(sd_train.Vangover[labels],20,(0,10),color='red',alpha=0.5,label='has support material', histtype='step', stacked=False, fill=False,linewidth=5)
h2=plt.hist(sd_train.Vangover[~labels],20,(0,10),color='blue',alpha=0.5,label='no support material', histtype='step', stacked=False, fill=False, linewidth=5)
#plt.legend(loc='upper right')
plt.yscale('log')
plt.ylabel('# of Entries')
plt.xlabel('Volume Below Overhang (cm^3)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
plt.savefig(outdir+'/Vangover_sup0_vs_sup1.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vmes/sd_train.Vfil<1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vmes/sd_train.Vfil>1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='black',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vsup<10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vsup>10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='blue',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil_cutVsup.png')

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_basic = tdr(sd_train[['Vmes','Vch','Vbb','Sa','X','Z']].as_matrix(),sd_train['t'].as_matrix(),'huber',"TrainData_basic6var")
lregtrain_basic.transform()
lregtrain_basic.fit()
lregtrain_basic.predict()
lregtrain_basic.PlotPerformance(1,1000,'log',False)
lregtrain_basic.export_model()
# Out:
# Regression TrainData_basic6var_huber --- 1822 entries
# residual standard error (rse): 1791.37531189 residual mean_absolute_error: 296.749612594 residual mad 44.7489588085 296.749612594 <y>:  1116.30731797
# ratio (err):  0.26583146757
# R^2 score:  0.510483850612

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_ols = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'ols',"TrainData_6var")
lregtrain_ols.transform()
lregtrain_ols.fit()
lregtrain_ols.predict()
lregtrain_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_ols --- 1822 entries
# coeffecients:
# 1116.30731797
# [ 1285.32050173   800.12988407    15.67232833  -288.49016609   -97.20751646
#    588.15964116]
# residual standard error (rse): 1639.99447573 residual mean_absolute_error: 408.231465479 residual mad 122.034399174 408.231465479 <y>:  1116.30731797
# ratio (err):  0.365698100254
# R^2 score:  0.589721626622

# %%
lregtrain = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'ols',"TrainData_6var")
lregtrain.transform()
lregtrain.fit()
lregtrain.predict()
lregtrain.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_ols --- 1822 entries
# coeffecients:
# 1116.30731797
# [ 1285.32050173   800.12988407    15.67232833  -288.49016609   -97.20751646
#    588.15964116]
# residual standard error (rse): 1639.99447573 residual mean_absolute_error: 408.231465479 residual mad 122.034399174 408.231465479 <y>:  1116.30731797
# ratio (err):  0.365698100254
# R^2 score:  0.589721626622

# %% [markdown]
# ## Test

# %%
lregtest_ols = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'ols',"TestData_6var")
lregtest_ols.scaler = lregtrain_basic.scaler
lregtest_ols.regr = lregtrain_basic.regr
lregtest_ols.transform()
lregtest_ols.predict()
lregtest_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TestData_6var_ols --- 911 entries
# residual standard error (rse): 5034.20502993 residual mean_absolute_error: 823.054047508 residual mad 71.5805850571 823.054047508 <y>:  975.963757775
# ratio (err):  0.843324396988
# R^2 score:  -6.30390719349

# %%
lregtest = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'ols',"TestData_6var")
lregtest.scaler = lregtrain.scaler
lregtest.regr = lregtrain.regr
lregtest.transform()
lregtest.predict()
lregtest.PlotPerformance(0.5,1000,'log',False)
# Out:
# Regression TestData_6var_ols --- 911 entries
# residual standard error (rse): 1347.1183113 residual mean_absolute_error: 381.253152764 residual mad 118.617186081 381.253152764 <y>:  975.963757775
# ratio (err):  0.390642736195
# R^2 score:  0.476996100726

# %% [markdown]
# ## Cross-Validation

# %%
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
from TDPPredictor import TDPClassifier as tdc

from sklearn.model_selection import KFold
kf = KFold(n_splits=8)
print kf.get_n_splits(lregtrain.X)
print(kf)
# Out:
# 8
# KFold(n_splits=8, random_state=None, shuffle=False)

# %%
len(sd_test_train)
X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix()
#X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','X']].as_matrix()
y_cv = sd_test_train['t'].as_matrix()

ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

for train_index, test_index in kf.split(X_cv):
    print '================================ Fold',ct
    #print("TRAIN:", train_index, "TEST:", test_index)


    # first train combined dataset
    X_all_cv_train, X_all_cv_test = X_cv[train_index], X_cv[test_index]
    y_all_cv_train, y_all_cv_test = y_cv[train_index], y_cv[test_index]
    
    regr_cv_train_all = tdr(X_all_cv_train,y_all_cv_train,'ols','cv_train_all_f%d'%ct)
    regr_cv_train_all.transform()
    regr_cv_train_all.fit()

    regr_cv_test_all = tdr(X_all_cv_test,y_all_cv_test,'ols','cv_test_all_f%d'%ct)
    regr_cv_test_all.scaler = regr_cv_train_all.scaler
    regr_cv_test_all.regr = regr_cv_train_all.regr
    regr_cv_test_all.transform()
    regr_cv_test_all.predict()
    regr_cv_test_all.PlotPerformance(0.5,1000,'log')
    err_all.append(regr_cv_test_all.frac_ame)
    r2_all.append(regr_cv_test_all.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# Regression cv_train_all_f0_ols --- 2391 entries
# coeffecients:
# 1077.73382127
# [ 1245.9034468    953.20610645   -81.5600656   -148.64848466   -60.73423058
#    257.18820081]
# Regression cv_test_all_f0_ols --- 342 entries
# residual standard error (rse): 767.203563041 residual mean_absolute_error: 299.778942462 residual mad 92.3303685751 299.778942462 <y>:  1012.14429825
# ratio (err):  0.29618201968
# R^2 score:  0.775346286627
# ================================ Fold 1
# Regression cv_train_all_f1_ols --- 2391 entries
# coeffecients:
# 1054.65100376
# [ 1298.57081717   604.46542161    22.11885076    -9.16089388   -37.39926199
#    192.35132942]
# Regression cv_test_all_f1_ols --- 342 entries
# residual standard error (rse): 2251.5385955 residual mean_absolute_error: 381.493944443 residual mad 72.2506160887 381.493944443 <y>:  1173.52153996
# ratio (err):  0.325084739779
# R^2 score:  0.440563546591
# ================================ Fold 2
# Regression cv_train_all_f2_ols --- 2391 entries
# coeffecients:
# 1072.88038478
# [ 1223.40142405   885.14691203    -6.66601552  -157.67689725   -54.05240583
#    244.80668656]
# Regression cv_test_all_f2_ols --- 342 entries
# residual standard error (rse): 1020.32393015 residual mean_absolute_error: 347.591282377 residual mad 108.406064525 347.591282377 <y>:  1046.07577973
# ratio (err):  0.332281168452
# R^2 score:  0.726264475618
# ================================ Fold 3
# Regression cv_train_all_f3_ols --- 2391 entries
# coeffecients:
# 1077.99310609
# [ 1346.07446999   561.53830267    36.32468202     6.4697043    -17.304239
#    194.12087617]
# Regression cv_test_all_f3_ols --- 342 entries
# residual standard error (rse): 2270.98040969 residual mean_absolute_error: 366.180994367 residual mad 76.9804673559 366.180994367 <y>:  1010.33157895
# ratio (err):  0.362436453534
# R^2 score:  0.35679893521
# ================================ Fold 4
# Regression cv_train_all_f4_ols --- 2391 entries
# coeffecients:
# 1016.13858218
# [ 1168.36882653   980.09150538  -275.02469679  -144.43298469   -64.09043782
#    235.50414759]
# Regression cv_test_all_f4_ols --- 342 entries
# residual standard error (rse): 1953.95442281 residual mean_absolute_error: 471.306045536 residual mad 95.4614918415 471.306045536 <y>:  1442.77066277
# ratio (err):  0.326667333692
# R^2 score:  0.65229733278
# ================================ Fold 5
# Regression cv_train_all_f5_ols --- 2392 entries
# coeffecients:
# 1076.00597129
# [ 1191.03076325   806.37566861   122.32049325  -192.42355801   -44.9811201
#    236.6220246 ]
# Regression cv_test_all_f5_ols --- 341 entries
# residual standard error (rse): 1173.27911427 residual mean_absolute_error: 398.514130323 residual mad 110.524545752 398.514130323 <y>:  1024.07223851
# ratio (err):  0.389146502888
# R^2 score:  0.686150620446
# ================================ Fold 6
# Regression cv_train_all_f6_ols --- 2392 entries
# coeffecients:
# 1079.01709169
# [ 1306.08845423   700.71891156   -65.44729097  -162.78954517   -85.32521811
#    498.84697533]
# Regression cv_test_all_f6_ols --- 341 entries
# residual standard error (rse): 1487.26029327 residual mean_absolute_error: 341.404546354 residual mad 95.6304227887 341.404546354 <y>:  1002.95024438
# ratio (err):  0.340400282335
# R^2 score:  0.372530286206
# ================================ Fold 7
# Regression cv_train_all_f7_ols --- 2392 entries
# coeffecients:
# 1101.76892419
# [ 1275.9267905    867.26685576   -25.37147255  -123.27644658   -51.9722823
#    263.71293855]
# Regression cv_test_all_f7_ols --- 341 entries
# residual standard error (rse): 508.021785261 residual mean_absolute_error: 238.923795696 residual mad 89.7909732959 238.923795696 <y>:  843.353812317
# ratio (err):  0.283301969122
# R^2 score:  0.840691963035

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_all)
h=plt.hist(err_all,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_all)
h=plt.hist(r2_all,20,(0,1))
# Out:
# 0.331937558685
# 0.606330430814

# %%
ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

#X_clf_cv = sd_test_train[['Vangover','diffVchVmes','Sa']].as_matrix()
X_clf_cv = sd_test_train[['Vangover','diffVchVmes']].as_matrix()
#X_clf_cv = sd_test_train[['Vsup']].as_matrix()
y_clf_cv = ((sd_test_train['Vsup']>0.1).as_matrix()).astype(np.float)

for train_index, test_index in kf.split(X_clf_cv):
    print '================================ Fold',ct
    # now train classifier
    X_clf_train, X_clf_test = X_clf_cv[train_index], X_clf_cv[test_index]
    y_clf_train, y_clf_test = y_clf_cv[train_index], y_clf_cv[test_index]
    print len(X_clf_train),len(y_clf_train),len(X_clf_test),len(y_clf_test)
    clf_cv_train =tdc(X_clf_train,y_clf_train)
    clf_cv_train.transform()
    clf_cv_train.fit()
    clf_cv_train.predict()
    # now test classifier
    clf_cv_test =tdc(X_clf_test,y_clf_test)
    clf_cv_test.clf = clf_cv_train.clf
    clf_cv_test.scaler = clf_cv_train.scaler
    clf_cv_test.transform()
    clf_cv_test.predict()
    
    # regression
    X_train, X_test = X_cv[train_index], X_cv[test_index]
    y_train, y_test = y_cv[train_index], y_cv[test_index]
    # train and test for no support volume
    regr_cv_train_sup0 = tdr(X_train[clf_cv_train.yhat==0],y_train[clf_cv_train.yhat==0],'ols','cv_train_sup0_f%d'%ct)
    regr_cv_train_sup0.transform()
    regr_cv_train_sup0.fit()

    regr_cv_test_sup0 = tdr(X_test[clf_cv_test.yhat==0],y_test[clf_cv_test.yhat==0],'ols','cv_test_sup0_f%d'%ct)
    if len(regr_cv_test_sup0.X) < 10:
        continue
    regr_cv_test_sup0.scaler = regr_cv_train_sup0.scaler
    regr_cv_test_sup0.regr = regr_cv_train_sup0.regr
    regr_cv_test_sup0.transform()
    regr_cv_test_sup0.predict()
    #regr_cv_test_sup0.PlotPerformance(0.5,1000,'log')
    err_sup0.append(regr_cv_test_sup0.frac_ame)
    r2_sup0.append(regr_cv_test_sup0.R2)

    #now train and test regression for with support volume
    regr_cv_train_sup1 = tdr(X_train[clf_cv_train.yhat==1],y_train[clf_cv_train.yhat==1],'ols','cv_train_sup1_f%d'%ct)
    regr_cv_train_sup1.transform()
    regr_cv_train_sup1.fit()

    regr_cv_test_sup1 = tdr(X_test[clf_cv_test.yhat==1],y_test[clf_cv_test.yhat==1],'ols','cv_test_sup1_f%d'%ct)
    if len(regr_cv_test_sup1.X) < 10:
        continue
    regr_cv_test_sup1.scaler = regr_cv_train_sup1.scaler
    regr_cv_test_sup1.regr = regr_cv_train_sup1.regr
    regr_cv_test_sup1.transform()
    regr_cv_test_sup1.predict()
    #regr_cv_test_sup1.PlotPerformance(0.5,1000,'log')
    err_sup1.append(regr_cv_test_sup1.frac_ame)
    r2_sup1.append(regr_cv_test_sup1.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.26204054]
# [[ 6.97197114  0.26296586]]
# [[836 164]
#  [403 988]]
# Classifier train --- 342 entries
# [[115  27]
#  [ 56 144]]
# Regression cv_train_sup0_f0_ols --- 1239 entries
# coeffecients:
# 454.448964218
# [ 530.8166453   163.23525696 -105.74539662   16.9293049   -10.42631552
#    25.02908748]
# Regression cv_test_sup0_f0_ols --- 171 entries
# residual standard error (rse): 636.334739254 residual mean_absolute_error: 148.047146284 residual mad 38.2157049935 148.047146284 <y>:  533.211403509
# ratio (err):  0.277651875615
# R^2 score:  0.584111685443
# Regression cv_train_sup1_f0_ols --- 1152 entries
# coeffecients:
# 1748.08967014
# [ 1641.64161333  1327.38523121   -66.21608119  -284.72659123  -110.58686658
#    369.82119977]
# Regression cv_test_sup1_f0_ols --- 171 entries
# residual standard error (rse): 892.505971026 residual mean_absolute_error: 439.746990012 residual mad 156.228437914 439.746990012 <y>:  1491.07719298
# ratio (err):  0.294918996871
# R^2 score:  0.790800570169
# ================================ Fold 1
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.18449071]
# [[ 6.90815864  0.17536349]]
# [[859 152]
#  [422 958]]
# Classifier train --- 342 entries
# [[117  14]
#  [ 69 142]]
# Regression cv_train_sup0_f1_ols --- 1281 entries
# coeffecients:
# 533.466887848
# [ 601.61859281  314.26789391  -87.67052982    5.96034002  -31.7896375
#    29.60471224]
# Regression cv_test_sup0_f1_ols --- 186 entries
# residual standard error (rse): 248.964419832 residual mean_absolute_error: 123.088709877 residual mad 50.3852563154 123.088709877 <y>:  429.230197133
# ratio (err):  0.286766193757
# R^2 score:  0.661646133809
# Regression cv_train_sup1_f1_ols --- 1110 entries
# coeffecients:
# 1656.12564565
# [ 1697.44961659   870.54961541    39.25412865   -78.28289253   -51.29545368
#    283.38151093]
# Regression cv_test_sup1_f1_ols --- 156 entries
# residual standard error (rse): 3314.22933815 residual mean_absolute_error: 680.459703524 residual mad 121.689113473 680.459703524 <y>:  2060.94583333
# ratio (err):  0.330168650004
# R^2 score:  0.396461065319
# ================================ Fold 2
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.28357466]
# [[ 7.00277088  0.21143913]]
# [[ 825  168]
#  [ 382 1016]]
# Classifier train --- 342 entries
# [[126  23]
#  [ 54 139]]
# Regression cv_train_sup0_f2_ols --- 1207 entries
# coeffecients:
# 470.158077879
# [ 599.63688471  144.80842366  -55.31234759   31.21996675   -8.68591833
#    17.68676018]
# Regression cv_test_sup0_f2_ols --- 180 entries
# residual standard error (rse): 404.946711435 residual mean_absolute_error: 145.806301016 residual mad 38.7007963712 145.806301016 <y>:  488.078240741
# ratio (err):  0.29873550764
# R^2 score:  0.562223513828
# Regression cv_train_sup1_f2_ols --- 1184 entries
# coeffecients:
# 1687.31097973
# [ 1571.5313343   1257.34983239    14.93187291  -309.34771586  -109.25728117
#    349.51831695]
# Regression cv_test_sup1_f2_ols --- 162 entries
# residual standard error (rse): 1441.25378941 residual mean_absolute_error: 556.724926329 residual mad 191.898628125 556.724926329 <y>:  1666.07304527
# ratio (err):  0.334153972367
# R^2 score:  0.698182590025
# ================================ Fold 3
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.40646322]
# [[ 7.75632504  0.23672111]]
# [[ 833  154]
#  [ 390 1014]]
# Classifier train --- 342 entries
# [[118  37]
#  [ 50 137]]
# Regression cv_train_sup0_f3_ols --- 1223 entries
# coeffecients:
# 471.583047152
# [ 588.37801111  191.95777237  -81.85183437    1.6586292   -13.9178776
#    25.76353929]
# Regression cv_test_sup0_f3_ols --- 168 entries
# residual standard error (rse): 439.927802504 residual mean_absolute_error: 126.035808142 residual mad 32.656258573 126.035808142 <y>:  475.457539683
# ratio (err):  0.265083204331
# R^2 score:  0.572835401162
# Regression cv_train_sup1_f3_ols --- 1168 entries
# coeffecients:
# 1712.95843322
# [ 1757.91769672   760.3374569     75.51174916   -34.4794467    -53.18060659
#    274.86774599]
# Regression cv_test_sup1_f3_ols --- 174 entries
# residual standard error (rse): 3150.80243226 residual mean_absolute_error: 590.421397023 residual mad 158.504100666 590.421397023 <y>:  1526.76168582
# ratio (err):  0.386714837361
# R^2 score:  0.328295591972
# ================================ Fold 4
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.13629876]
# [[ 6.44519776  0.19008794]]
# [[ 827  171]
#  [ 386 1007]]
# Classifier train --- 342 entries
# [[119  25]
#  [ 40 158]]
# Regression cv_train_sup0_f4_ols --- 1213 entries
# coeffecients:
# 462.39281396
# [ 422.61136047  151.23655901  -75.982069     10.78457624  -13.29272452
#    26.92050034]
# Regression cv_test_sup0_f4_ols --- 159 entries
# residual standard error (rse): 413.7702918 residual mean_absolute_error: 101.41534728 residual mad 38.3640558911 101.41534728 <y>:  473.125366876
# ratio (err):  0.214351954851
# R^2 score:  0.897887596438
# Regression cv_train_sup1_f4_ols --- 1178 entries
# coeffecients:
# 1586.3368987
# [ 1535.6510276   1351.34654394  -346.50890809  -258.58263575  -100.26459024
#    334.23719493]
# Regression cv_test_sup1_f4_ols --- 183 entries
# residual standard error (rse): 2641.11393479 residual mean_absolute_error: 776.218735668 residual mad 167.15073944 776.218735668 <y>:  2285.24936248
# ratio (err):  0.339664786003
# R^2 score:  0.60225203366
# ================================ Fold 5
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.32102712]
# [[ 7.54004714  0.13931427]]
# [[859 140]
#  [410 983]]
# Classifier train --- 341 entries
# [[118  25]
#  [ 62 136]]
# Regression cv_train_sup0_f5_ols --- 1269 entries
# coeffecients:
# 535.27416601
# [ 649.33070479  260.58803776  -91.48765737   12.95211888  -24.92977619
#    30.17477358]
# Regression cv_test_sup0_f5_ols --- 180 entries
# residual standard error (rse): 386.776706963 residual mean_absolute_error: 140.088540469 residual mad 44.8818435954 140.088540469 <y>:  457.114444444
# ratio (err):  0.306462729787
# R^2 score:  0.515838158823
# Regression cv_train_sup1_f5_ols --- 1123 entries
# coeffecients:
# 1687.03772633
# [ 1529.25604811  1205.90399101   197.49824079  -406.80108021   -54.92275337
#    346.29481148]
# Regression cv_test_sup1_f5_ols --- 161 entries
# residual standard error (rse): 1684.59383079 residual mean_absolute_error: 677.343690495 residual mad 230.620057467 677.343690495 <y>:  1657.93809524
# ratio (err):  0.408545827157
# R^2 score:  0.653212484861
# ================================ Fold 6
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.26599498]
# [[ 5.381229    0.18699238]]
# [[828 160]
#  [407 997]]
# Classifier train --- 341 entries
# [[135  19]
#  [ 54 133]]
# Regression cv_train_sup0_f6_ols --- 1235 entries
# coeffecients:
# 512.854952767
# [ 504.58359193  378.38887767 -111.17179289   -5.65055902  -31.60349689
#    39.13806114]
# Regression cv_test_sup0_f6_ols --- 189 entries
# residual standard error (rse): 224.748686981 residual mean_absolute_error: 124.800622195 residual mad 55.6038801025 124.800622195 <y>:  554.838095238
# ratio (err):  0.224931603049
# R^2 score:  0.945920371603
# Regression cv_train_sup1_f6_ols --- 1157 entries
# coeffecients:
# 1683.34746471
# [ 1687.64573089  1048.02210619   -73.66630529  -352.02182177  -128.35967755
#    720.98441157]
# Regression cv_test_sup1_f6_ols --- 152 entries
# residual standard error (rse): 2289.66790342 residual mean_absolute_error: 611.614072046 residual mad 155.583128803 611.614072046 <y>:  1560.14232456
# ratio (err):  0.392024536748
# R^2 score:  0.152635280634
# ================================ Fold 7
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.14330159]
# [[ 6.60838286  0.1957845 ]]
# [[867 151]
#  [443 931]]
# Classifier train --- 341 entries
# [[113  11]
#  [ 72 145]]
# Regression cv_train_sup0_f7_ols --- 1310 entries
# coeffecients:
# 534.739707379
# [ 590.19872588  337.08450181 -101.66104588    6.77957098  -24.90057719
#    30.80269466]
# Regression cv_test_sup0_f7_ols --- 185 entries
# residual standard error (rse): 298.132114824 residual mean_absolute_error: 131.377804597 residual mad 48.4043425676 131.377804597 <y>:  426.718288288
# ratio (err):  0.307879479748
# R^2 score:  0.45721636708
# Regression cv_train_sup1_f7_ols --- 1082 entries
# coeffecients:
# 1788.28304067
# [ 1675.58620667  1304.1073778    -23.2996457   -295.50776356   -78.147312
#    395.09012369]
# Regression cv_test_sup1_f7_ols --- 156 entries
# residual standard error (rse): 703.869242049 residual mean_absolute_error: 369.242845528 residual mad 176.139138337 369.242845528 <y>:  1337.44081197
# ratio (err):  0.276081634585
# R^2 score:  0.828989241813

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup0)
h=plt.hist(err_sup0,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup0)
h=plt.hist(r2_sup0,20,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup1)
h=plt.hist(err_sup1,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup1)
h=plt.hist(r2_sup1,20,(0,1))
# Out:
# 0.272732818597
# 0.649709903523
# 0.345284155137
# 0.556353607307
