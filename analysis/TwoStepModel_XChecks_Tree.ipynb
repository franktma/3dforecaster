# %%
# standing data tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# sklearn
from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
# persistence
from sklearn.externals import joblib

from TDPPredictor import *

# %matplotlib inline

# %%
Tag='XChecks'
outdir='fig/'+Tag
import os
os.system('mkdir -p '+outdir)
#Load the dataset
data=pd.read_csv('../data/round2/batch2_all_viable_merged_v2.csv')
setup_df(data)                 
data.info()
# Out:
# before conversion: 28401
# after conversion: 473.35
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB

# %%
#filter dataset
Vmin=1.
Vmax=2000.
anafilter=(data['Vmes']>Vmin)&(data['Vmes']<Vmax)&(data['Watertight']==True)
sd=data[anafilter]

# cut numbers
ndata=len(data)
nselected=len(sd)
ntrain=np.int(nselected*0.6)
nval=np.int(nselected*0.3)
print 'total input:', ndata, 'total selected:', nselected, 'selection efficiency:', np.divide(nselected,np.float(ndata))
# test first on the training set
sd_test_train = sd.head(ntrain+nval)
sd_train = sd_test_train.head(ntrain)
sd_test = sd_test_train.tail(nval)
print 'train on:',len(sd_train), 'testing on:',len(sd_test)
# Out:
# total input: 3050 total selected: 3038 selection efficiency: 0.99606557377
# train on: 1822 testing on: 911

# %%
sd_train[['t','Vfil','Vsup','sumV','Vmes','Vbb','Vch','Sa','Z','rSaVmes','rVbbVmes','rVchVmes','Vangover']].corr()
# Out:
#                  t      Vfil      Vsup      sumV      Vmes       Vbb  \
# t         1.000000  0.731170  0.757996  0.985809  0.696076  0.652653
# Vfil      0.731170  1.000000  0.113160  0.830461  0.962030  0.684058
# Vsup      0.757996  0.113160  1.000000  0.647473  0.100064  0.263596
# sumV      0.985809  0.830461  0.647473  1.000000  0.793995  0.672475
# Vmes      0.696076  0.962030  0.100064  0.793995  1.000000  0.696310
# Vbb       0.652653  0.684058  0.263596  0.672475  0.696310  1.000000
# Vch       0.666812  0.683538  0.279585  0.681041  0.683988  0.918530
# Sa        0.559169  0.600305  0.191505  0.567816  0.599424  0.792680
# Z         0.401319  0.450621  0.117129  0.411304  0.458004  0.594044
# rSaVmes  -0.185031 -0.269297 -0.018245 -0.216784 -0.270555 -0.123221
# rVbbVmes  0.007033 -0.080810  0.072667 -0.021240 -0.083200  0.268548
# rVchVmes  0.030843 -0.085153  0.101885 -0.008189 -0.090378  0.301817
# Vangover  0.462097  0.264528  0.392042  0.422706  0.265489  0.530236
#
#                Vch        Sa         Z   rSaVmes  rVbbVmes  rVchVmes  Vangover
# t         0.666812  0.559169  0.401319 -0.185031  0.007033  0.030843  0.462097
# Vfil      0.683538  0.600305  0.450621 -0.269297 -0.080810 -0.085153  0.264528
# Vsup      0.279585  0.191505  0.117129 -0.018245  0.072667  0.101885  0.392042
# sumV      0.681041  0.567816  0.411304 -0.216784 -0.021240 -0.008189  0.422706
# Vmes      0.683988  0.599424  0.458004 -0.270555 -0.083200 -0.090378  0.265489
# Vbb       0.918530  0.792680  0.594044 -0.123221  0.268548  0.301817  0.530236
# Vch       1.000000  0.863465  0.544688 -0.114844  0.177089  0.283573  0.536702
# Sa        0.863465  1.000000  0.504484 -0.031730  0.081687  0.187540  0.502332
# Z         0.544688  0.504484  1.000000 -0.179573  0.157062  0.167578  0.402033
# rSaVmes  -0.114844 -0.031730 -0.179573  1.000000  0.441234  0.557743 -0.013461
# rVbbVmes  0.177089  0.081687  0.157062  0.441234  1.000000  0.871745  0.126944
# rVchVmes  0.283573  0.187540  0.167578  0.557743  0.871745  1.000000  0.186679
# Vangover  0.536702  0.502332  0.402033 -0.013461  0.126944  0.186679  1.000000

# %% [markdown]
# ## Train

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
axes.scatter(sd_train.Vmes,sd_train.t/60, color='red',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
plt.xlabel('Extracted Volume (cm^3)')
plt.ylabel('Build Time (hours)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('Build Time (hours)', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t.png')

# %% [markdown]
# ## Overhang

# %%
labels=(sd.Vsup<0.1)
len(labels)
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
h1=plt.hist(sd_train.Vangover[labels],20,(0,10),color='red',alpha=0.5,label='has support material', histtype='step', stacked=False, fill=False,linewidth=5)
h2=plt.hist(sd_train.Vangover[~labels],20,(0,10),color='blue',alpha=0.5,label='no support material', histtype='step', stacked=False, fill=False, linewidth=5)
#plt.legend(loc='upper right')
plt.yscale('log')
plt.ylabel('# of Entries')
plt.xlabel('Volume Below Overhang (cm^3)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
plt.savefig(outdir+'/Vangover_sup0_vs_sup1.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vmes/sd_train.Vfil<1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vmes/sd_train.Vfil>1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='black',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vsup<10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vsup>10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='blue',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil_cutVsup.png')

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_basic = tdr(sd_train[['Vmes','Vch','Vbb','Sa','X','Z']].as_matrix(),sd_train['t'].as_matrix(),'tree',"TrainData_basic6var")
lregtrain_basic.transform()
lregtrain_basic.fit()
lregtrain_basic.predict()
lregtrain_basic.PlotPerformance(1,1000,'log',False)
lregtrain_basic.export_model()
# Out:
# Regression TrainData_basic6var_tree --- 1822 entries
# tree feature importances
# [ 0.70692371  0.16230157  0.0185091   0.00226311  0.10429537  0.00570714]
# residual standard error (rse): 770.068957389 residual mean_absolute_error: 260.803132293 residual mad 106.125 260.803132293 <y>:  1116.30731797
# ratio (err):  0.233630227174
# R^2 score:  0.909540728039

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_ols = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'ols',"TrainData_6var")
lregtrain_ols.transform()
lregtrain_ols.fit()
lregtrain_ols.predict()
lregtrain_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_ols --- 1822 entries
# coeffecients:
# 1116.30731797
# [ 1285.32050173   800.12988407    15.67232833  -288.49016609   -97.20751646
#    588.15964116]
# residual standard error (rse): 1639.99447573 residual mean_absolute_error: 408.231465479 residual mad 122.034399174 408.231465479 <y>:  1116.30731797
# ratio (err):  0.365698100254
# R^2 score:  0.589721626622

# %%
lregtrain = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'tree',"TrainData_6var")
lregtrain.transform()
lregtrain.fit()
lregtrain.predict()
lregtrain.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_tree --- 1822 entries
# tree feature importances
# [ 0.59788349  0.05917022  0.01781626  0.00896373  0.13853351  0.1776328 ]
# residual standard error (rse): 542.958842581 residual mean_absolute_error: 232.828778816 residual mad 100.914001372 232.828778816 <y>:  1116.30731797
# ratio (err):  0.208570503005
# R^2 score:  0.955029504217

# %% [markdown]
# ## Test

# %%
lregtest_ols = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'ols',"TestData_6var")
lregtest_ols.scaler = lregtrain_basic.scaler
lregtest_ols.regr = lregtrain_basic.regr
lregtest_ols.transform()
lregtest_ols.predict()
lregtest_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TestData_6var_ols --- 911 entries
# residual standard error (rse): 1070.60297951 residual mean_absolute_error: 375.878858907 residual mad 117.516666667 375.878858907 <y>:  975.963757775
# ratio (err):  0.38513608309
# R^2 score:  0.669668230972

# %%
lregtest = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'tree',"TestData_6var")
lregtest.scaler = lregtrain.scaler
lregtest.regr = lregtrain.regr
lregtest.transform()
lregtest.predict()
lregtest.PlotPerformance(0.5,1000,'log',False)
# Out:
# Regression TestData_6var_tree --- 911 entries
# residual standard error (rse): 2314.56741233 residual mean_absolute_error: 452.587544213 residual mad 111.566666667 452.587544213 <y>:  975.963757775
# ratio (err):  0.463733966151
# R^2 score:  -0.543949588959

# %% [markdown]
# ## Cross-Validation

# %%
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
from TDPPredictor import TDPClassifier as tdc

from sklearn.model_selection import KFold
kf = KFold(n_splits=8)
print kf.get_n_splits(lregtrain.X)
print(kf)
# Out:
# 8
# KFold(n_splits=8, random_state=None, shuffle=False)

# %%
len(sd_test_train)
X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix()
#X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','X']].as_matrix()
y_cv = sd_test_train['t'].as_matrix()

ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

for train_index, test_index in kf.split(X_cv):
    print '================================ Fold',ct
    #print("TRAIN:", train_index, "TEST:", test_index)


    # first train combined dataset
    X_all_cv_train, X_all_cv_test = X_cv[train_index], X_cv[test_index]
    y_all_cv_train, y_all_cv_test = y_cv[train_index], y_cv[test_index]
    
    regr_cv_train_all = tdr(X_all_cv_train,y_all_cv_train,'tree','cv_train_all_f%d'%ct)
    regr_cv_train_all.transform()
    regr_cv_train_all.fit()

    regr_cv_test_all = tdr(X_all_cv_test,y_all_cv_test,'tree','cv_test_all_f%d'%ct)
    regr_cv_test_all.scaler = regr_cv_train_all.scaler
    regr_cv_test_all.regr = regr_cv_train_all.regr
    regr_cv_test_all.transform()
    regr_cv_test_all.predict()
    regr_cv_test_all.PlotPerformance(0.5,1000,'log')
    err_all.append(regr_cv_test_all.frac_ame)
    r2_all.append(regr_cv_test_all.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# Regression cv_train_all_f0_tree --- 2391 entries
# tree feature importances
# [ 0.6744892   0.1370374   0.01412915  0.00610108  0.00832114  0.15992203]
# Regression cv_test_all_f0_tree --- 342 entries
# residual standard error (rse): 2438.20477013 residual mean_absolute_error: 450.059334857 residual mad 117.518832214 450.059334857 <y>:  1012.14429825
# ratio (err):  0.444659260184
# R^2 score:  -1.26899078729
# ================================ Fold 1
# Regression cv_train_all_f1_tree --- 2391 entries
# tree feature importances
# [ 0.63590496  0.16502507  0.05537785  0.10924757  0.00779914  0.02664541]
# Regression cv_test_all_f1_tree --- 342 entries
# residual standard error (rse): 3489.21200642 residual mean_absolute_error: 555.821885837 residual mad 100.133257092 555.821885837 <y>:  1173.52153996
# ratio (err):  0.473635861729
# R^2 score:  -0.343527890669
# ================================ Fold 2
# Regression cv_train_all_f2_tree --- 2391 entries
# tree feature importances
# [ 0.69580886  0.17917991  0.00880341  0.10075115  0.00120786  0.01424881]
# Regression cv_test_all_f2_tree --- 342 entries
# residual standard error (rse): 1136.72737872 residual mean_absolute_error: 349.217468541 residual mad 106.784365077 349.217468541 <y>:  1046.07577973
# ratio (err):  0.333835727114
# R^2 score:  0.660243590913
# ================================ Fold 3
# Regression cv_train_all_f3_tree --- 2391 entries
# tree feature importances
# [ 0.73631722  0.0320458   0.03131596  0.10355169  0.00714068  0.08962866]
# Regression cv_test_all_f3_tree --- 342 entries
# residual standard error (rse): 1017.48068001 residual mean_absolute_error: 328.759606739 residual mad 118.237396955 328.759606739 <y>:  1010.33157895
# ratio (err):  0.325397734358
# R^2 score:  0.870886301405
# ================================ Fold 4
# Regression cv_train_all_f4_tree --- 2391 entries
# tree feature importances
# [  6.44751029e-01   7.78356308e-03   5.08621497e-03   1.51488997e-02
#    5.52850311e-04   3.26677443e-01]
# Regression cv_test_all_f4_tree --- 342 entries
# residual standard error (rse): 1986.40054321 residual mean_absolute_error: 497.507225407 residual mad 93.8619501437 497.507225407 <y>:  1442.77066277
# ratio (err):  0.344827655736
# R^2 score:  0.640654000652
# ================================ Fold 5
# Regression cv_train_all_f5_tree --- 2392 entries
# tree feature importances
# [ 0.68009232  0.00758113  0.02448642  0.13085629  0.00134899  0.15563486]
# Regression cv_test_all_f5_tree --- 341 entries
# residual standard error (rse): 1531.47907598 residual mean_absolute_error: 481.609762199 residual mad 121.36496847 481.609762199 <y>:  1024.07223851
# ratio (err):  0.470288856671
# R^2 score:  0.465262390786
# ================================ Fold 6
# Regression cv_train_all_f6_tree --- 2392 entries
# tree feature importances
# [ 0.57739493  0.26752455  0.0247388   0.00154883  0.00852532  0.12026757]
# Regression cv_test_all_f6_tree --- 341 entries
# residual standard error (rse): 2292.4221294 residual mean_absolute_error: 461.874750328 residual mad 90.1318927358 461.874750328 <y>:  1002.95024438
# ratio (err):  0.460516115248
# R^2 score:  -0.490760874882
# ================================ Fold 7
# Regression cv_train_all_f7_tree --- 2392 entries
# tree feature importances
# [ 0.60801431  0.16832731  0.02032425  0.11323867  0.00276505  0.08733041]
# Regression cv_test_all_f7_tree --- 341 entries
# residual standard error (rse): 693.751406091 residual mean_absolute_error: 272.530073975 residual mad 130.397421378 272.530073975 <y>:  843.353812317
# ratio (err):  0.323150343302
# R^2 score:  0.702914971508

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_all)
h=plt.hist(err_all,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_all)
h=plt.hist(r2_all,20,(0,1))
# Out:
# 0.397038944293
# 0.154585212803

# %%
ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

#X_clf_cv = sd_test_train[['Vangover','diffVchVmes','Sa']].as_matrix()
X_clf_cv = sd_test_train[['Vangover','diffVchVmes']].as_matrix()
#X_clf_cv = sd_test_train[['Vsup']].as_matrix()
y_clf_cv = ((sd_test_train['Vsup']>0.1).as_matrix()).astype(np.float)

for train_index, test_index in kf.split(X_clf_cv):
    print '================================ Fold',ct
    # now train classifier
    X_clf_train, X_clf_test = X_clf_cv[train_index], X_clf_cv[test_index]
    y_clf_train, y_clf_test = y_clf_cv[train_index], y_clf_cv[test_index]
    print len(X_clf_train),len(y_clf_train),len(X_clf_test),len(y_clf_test)
    clf_cv_train =tdc(X_clf_train,y_clf_train)
    clf_cv_train.transform()
    clf_cv_train.fit()
    clf_cv_train.predict()
    # now test classifier
    clf_cv_test =tdc(X_clf_test,y_clf_test)
    clf_cv_test.clf = clf_cv_train.clf
    clf_cv_test.scaler = clf_cv_train.scaler
    clf_cv_test.transform()
    clf_cv_test.predict()
    
    # regression
    X_train, X_test = X_cv[train_index], X_cv[test_index]
    y_train, y_test = y_cv[train_index], y_cv[test_index]
    # train and test for no support volume
    regr_cv_train_sup0 = tdr(X_train[clf_cv_train.yhat==0],y_train[clf_cv_train.yhat==0],'tree','cv_train_sup0_f%d'%ct)
    regr_cv_train_sup0.transform()
    regr_cv_train_sup0.fit()

    regr_cv_test_sup0 = tdr(X_test[clf_cv_test.yhat==0],y_test[clf_cv_test.yhat==0],'tree','cv_test_sup0_f%d'%ct)
    if len(regr_cv_test_sup0.X) < 10:
        continue
    regr_cv_test_sup0.scaler = regr_cv_train_sup0.scaler
    regr_cv_test_sup0.regr = regr_cv_train_sup0.regr
    regr_cv_test_sup0.transform()
    regr_cv_test_sup0.predict()
    #regr_cv_test_sup0.PlotPerformance(0.5,1000,'log')
    err_sup0.append(regr_cv_test_sup0.frac_ame)
    r2_sup0.append(regr_cv_test_sup0.R2)

    #now train and test regression for with support volume
    regr_cv_train_sup1 = tdr(X_train[clf_cv_train.yhat==1],y_train[clf_cv_train.yhat==1],'tree','cv_train_sup1_f%d'%ct)
    regr_cv_train_sup1.transform()
    regr_cv_train_sup1.fit()

    regr_cv_test_sup1 = tdr(X_test[clf_cv_test.yhat==1],y_test[clf_cv_test.yhat==1],'tree','cv_test_sup1_f%d'%ct)
    if len(regr_cv_test_sup1.X) < 10:
        continue
    regr_cv_test_sup1.scaler = regr_cv_train_sup1.scaler
    regr_cv_test_sup1.regr = regr_cv_train_sup1.regr
    regr_cv_test_sup1.transform()
    regr_cv_test_sup1.predict()
    #regr_cv_test_sup1.PlotPerformance(0.5,1000,'log')
    err_sup1.append(regr_cv_test_sup1.frac_ame)
    r2_sup1.append(regr_cv_test_sup1.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.26204054]
# [[ 6.97197114  0.26296586]]
# [[836 164]
#  [403 988]]
# Classifier train --- 342 entries
# [[115  27]
#  [ 56 144]]
# Regression cv_train_sup0_f0_tree --- 1239 entries
# tree feature importances
# [ 0.39578066  0.0624447   0.4775491   0.00924083  0.03188891  0.02309581]
# Regression cv_test_sup0_f0_tree --- 171 entries
# residual standard error (rse): 920.397033542 residual mean_absolute_error: 214.7458923 residual mad 38.9671808832 214.7458923 <y>:  533.211403509
# ratio (err):  0.402740621988
# R^2 score:  0.129926639109
# Regression cv_train_sup1_f0_tree --- 1152 entries
# tree feature importances
# [ 0.63276234  0.13653412  0.03873272  0.00071096  0.01221765  0.17904221]
# Regression cv_test_sup1_f0_tree --- 171 entries
# residual standard error (rse): 3411.5099917 residual mean_absolute_error: 711.627554386 residual mad 219.213378784 711.627554386 <y>:  1491.07719298
# ratio (err):  0.477257353097
# R^2 score:  -2.05655018719
# ================================ Fold 1
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.18449071]
# [[ 6.90815864  0.17536349]]
# [[859 152]
#  [422 958]]
# Classifier train --- 342 entries
# [[117  14]
#  [ 69 142]]
# Regression cv_train_sup0_f1_tree --- 1281 entries
# tree feature importances
# [  3.62915077e-01   3.62186500e-01   1.62857989e-03   2.70653644e-01
#    2.88241648e-04   2.32795790e-03]
# Regression cv_test_sup0_f1_tree --- 186 entries
# residual standard error (rse): 245.600567793 residual mean_absolute_error: 119.334676873 residual mad 41.8531344697 119.334676873 <y>:  429.230197133
# ratio (err):  0.278020227073
# R^2 score:  0.67072761787
# Regression cv_train_sup1_f1_tree --- 1110 entries
# tree feature importances
# [ 0.59539488  0.18321293  0.05406341  0.12975491  0.          0.03757388]
# Regression cv_test_sup1_f1_tree --- 156 entries
# residual standard error (rse): 5312.71915072 residual mean_absolute_error: 1186.06584684 residual mad 174.633703278 1186.06584684 <y>:  2060.94583333
# ratio (err):  0.575495885266
# R^2 score:  -0.550864637438
# ================================ Fold 2
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.28357466]
# [[ 7.00277088  0.21143913]]
# [[ 825  168]
#  [ 382 1016]]
# Classifier train --- 342 entries
# [[126  23]
#  [ 54 139]]
# Regression cv_train_sup0_f2_tree --- 1207 entries
# tree feature importances
# [ 0.36246009  0.59595692  0.03598283  0.00215869  0.00161023  0.00183124]
# Regression cv_test_sup0_f2_tree --- 180 entries
# residual standard error (rse): 371.906633733 residual mean_absolute_error: 155.273578383 residual mad 54.1583333333 155.273578383 <y>:  488.078240741
# ratio (err):  0.318132556263
# R^2 score:  0.630746578498
# Regression cv_train_sup1_f2_tree --- 1184 entries
# tree feature importances
# [ 0.66468293  0.08885638  0.16183443  0.05489039  0.01254606  0.01718981]
# Regression cv_test_sup1_f2_tree --- 162 entries
# residual standard error (rse): 1804.01009197 residual mean_absolute_error: 638.716867575 residual mad 187.875 638.716867575 <y>:  1666.07304527
# ratio (err):  0.383366665339
# R^2 score:  0.527130515191
# ================================ Fold 3
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.40646322]
# [[ 7.75632504  0.23672111]]
# [[ 833  154]
#  [ 390 1014]]
# Classifier train --- 342 entries
# [[118  37]
#  [ 50 137]]
# Regression cv_train_sup0_f3_tree --- 1223 entries
# tree feature importances
# [  8.44453650e-01   1.12988627e-01   7.67579730e-03   1.69044924e-02
#    1.39104824e-05   1.79635229e-02]
# Regression cv_test_sup0_f3_tree --- 168 entries
# residual standard error (rse): 436.192722375 residual mean_absolute_error: 150.858293818 residual mad 59.9391537075 150.858293818 <y>:  475.457539683
# ratio (err):  0.31729078041
# R^2 score:  0.580058045219
# Regression cv_train_sup1_f3_tree --- 1168 entries
# tree feature importances
# [ 0.7058431   0.03333619  0.02389585  0.12937816  0.01267492  0.09487179]
# Regression cv_test_sup1_f3_tree --- 174 entries
# residual standard error (rse): 1737.2895045 residual mean_absolute_error: 601.94788981 residual mad 177.247270697 601.94788981 <y>:  1526.76168582
# ratio (err):  0.394264471921
# R^2 score:  0.795788476122
# ================================ Fold 4
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.13629876]
# [[ 6.44519776  0.19008794]]
# [[ 827  171]
#  [ 386 1007]]
# Classifier train --- 342 entries
# [[119  25]
#  [ 40 158]]
# Regression cv_train_sup0_f4_tree --- 1213 entries
# tree feature importances
# [ 0.62255169  0.27529216  0.00236747  0.02273592  0.04482806  0.0322247 ]
# Regression cv_test_sup0_f4_tree --- 159 entries
# residual standard error (rse): 703.011745316 residual mean_absolute_error: 148.212367115 residual mad 42.335976801 148.212367115 <y>:  473.125366876
# ratio (err):  0.313262356009
# R^2 score:  0.705228799999
# Regression cv_train_sup1_f4_tree --- 1178 entries
# tree feature importances
# [ 0.60122288  0.00834995  0.01985553  0.00644306  0.00075832  0.36337026]
# Regression cv_test_sup1_f4_tree --- 183 entries
# residual standard error (rse): 2867.38062047 residual mean_absolute_error: 922.685743499 residual mad 173.936358893 922.685743499 <y>:  2285.24936248
# ratio (err):  0.403757138564
# R^2 score:  0.531181883257
# ================================ Fold 5
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.32102712]
# [[ 7.54004714  0.13931427]]
# [[859 140]
#  [410 983]]
# Classifier train --- 341 entries
# [[118  25]
#  [ 62 136]]
# Regression cv_train_sup0_f5_tree --- 1269 entries
# tree feature importances
# [ 0.35550406  0.37095478  0.25872926  0.0007378   0.00548966  0.00858443]
# Regression cv_test_sup0_f5_tree --- 180 entries
# residual standard error (rse): 405.422701186 residual mean_absolute_error: 146.485291136 residual mad 53.196073157 146.485291136 <y>:  457.114444444
# ratio (err):  0.320456491622
# R^2 score:  0.468031323688
# Regression cv_train_sup1_f5_tree --- 1123 entries
# tree feature importances
# [ 0.63737957  0.01095574  0.03019671  0.00219864  0.1426197   0.17664965]
# Regression cv_test_sup1_f5_tree --- 161 entries
# residual standard error (rse): 4337.24136089 residual mean_absolute_error: 1124.43553867 residual mad 251.377938988 1124.43553867 <y>:  1657.93809524
# ratio (err):  0.678213222734
# R^2 score:  -1.29879489132
# ================================ Fold 6
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.26599498]
# [[ 5.381229    0.18699238]]
# [[828 160]
#  [407 997]]
# Classifier train --- 341 entries
# [[135  19]
#  [ 54 133]]
# Regression cv_train_sup0_f6_tree --- 1235 entries
# tree feature importances
# [  3.08043250e-01   3.54288431e-01   2.88931747e-01   4.55128922e-02
#    3.21449562e-03   9.18446485e-06]
# Regression cv_test_sup0_f6_tree --- 189 entries
# residual standard error (rse): 511.319333013 residual mean_absolute_error: 178.488573969 residual mad 60.3368261875 178.488573969 <y>:  554.838095238
# ratio (err):  0.321694879103
# R^2 score:  0.720086528892
# Regression cv_train_sup1_f6_tree --- 1157 entries
# tree feature importances
# [  5.28029625e-01   3.06227227e-01   3.76065725e-02   6.62596270e-03
#    1.96611432e-04   1.21314001e-01]
# Regression cv_test_sup1_f6_tree --- 152 entries
# residual standard error (rse): 3306.93858841 residual mean_absolute_error: 764.336804696 residual mad 139.730065045 764.336804696 <y>:  1560.14232456
# ratio (err):  0.489914793454
# R^2 score:  -0.767574164889
# ================================ Fold 7
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.14330159]
# [[ 6.60838286  0.1957845 ]]
# [[867 151]
#  [443 931]]
# Classifier train --- 341 entries
# [[113  11]
#  [ 72 145]]
# Regression cv_train_sup0_f7_tree --- 1310 entries
# tree feature importances
# [ 0.34917244  0.35221669  0.28143509  0.01676421  0.          0.00041156]
# Regression cv_test_sup0_f7_tree --- 185 entries
# residual standard error (rse): 659.969457736 residual mean_absolute_error: 166.343708757 residual mad 43.220376447 166.343708757 <y>:  426.718288288
# ratio (err):  0.38982090368
# R^2 score:  -1.6598484776
# Regression cv_train_sup1_f7_tree --- 1082 entries
# tree feature importances
# [ 0.57830143  0.13968537  0.0270875   0.01154635  0.01307352  0.23030583]
# Regression cv_test_sup1_f7_tree --- 156 entries
# residual standard error (rse): 1039.80096568 residual mean_absolute_error: 435.64270765 residual mad 185.816176745 435.64270765 <y>:  1337.44081197
# ratio (err):  0.325728588325
# R^2 score:  0.626801499553

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup0)
h=plt.hist(err_sup0,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup0)
h=plt.hist(r2_sup0,20,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup1)
h=plt.hist(err_sup1,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup1)
h=plt.hist(r2_sup1,20,(0,1))
# Out:
# 0.332677352019
# 0.28061963196
# 0.465999764838
# -0.274110188339
