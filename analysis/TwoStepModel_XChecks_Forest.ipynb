# %%
# standing data tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# sklearn
from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
# persistence
from sklearn.externals import joblib

from TDPPredictor import *

# %matplotlib inline

# %%
Tag='XChecks'
outdir='fig/'+Tag
import os
os.system('mkdir -p '+outdir)
#Load the dataset
data=pd.read_csv('../data/round2/batch2_all_viable_merged_v2.csv')
setup_df(data)                 
data.info()
# Out:
# before conversion: 28401
# after conversion: 473.35
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 53 columns):
# Unnamed: 0       3050 non-null int64
# File             3050 non-null object
# Output           3050 non-null object
# Cura Setting     3050 non-null object
# dh               3050 non-null float64
# t                3050 non-null float64
# Vfil             3050 non-null float64
# Vsup             3050 non-null float64
# Load Time        3050 non-null float64
# File Size        3050 non-null int64
# Time             3050 non-null float64
# Watertight       3050 non-null bool
# Time.1           3050 non-null float64
# NumBodies        3050 non-null float64
# Time.2           3050 non-null float64
# minZ             3050 non-null float64
# Time.3           3050 non-null float64
# X                3050 non-null float64
# Y                3050 non-null float64
# Z                3050 non-null float64
# Time.4           3050 non-null float64
# Vmes             3050 non-null float64
# Time.5           3050 non-null float64
# Sa               3050 non-null float64
# Time.6           3050 non-null float64
# Vbb              3050 non-null float64
# Time.7           3050 non-null float64
# Vbc              3050 non-null float64
# BC rad           3050 non-null float64
# Time.8           3050 non-null float64
# Vbs              3050 non-null float64
# Time.9           3050 non-null float64
# min primitive    3050 non-null object
# Vch              3050 non-null float64
# Time.10          3050 non-null float64
# Euler            3050 non-null float64
# Time.11          3050 non-null float64
# Sdown            3050 non-null float64
# Vdown            3050 non-null float64
# Sangover         3050 non-null float64
# Vangover         3050 non-null float64
# Time.12          3050 non-null float64
# Total Time       3050 non-null float64
# sumV             3050 non-null float64
# diffVbbVmes      3050 non-null float64
# diffVchVmes      3050 non-null float64
# rSaVmes          3050 non-null float64
# rVbbVmes         3050 non-null float64
# rVbcVmes         3050 non-null float64
# rVbsVmes         3050 non-null float64
# rVchVmes         3050 non-null float64
# rXVmes           3050 non-null float64
# rZVmes           3050 non-null float64
# dtypes: bool(1), float64(46), int64(2), object(4)
# memory usage: 1.2+ MB

# %%
#filter dataset
Vmin=1.
Vmax=2000.
anafilter=(data['Vmes']>Vmin)&(data['Vmes']<Vmax)&(data['Watertight']==True)
sd=data[anafilter]

# cut numbers
ndata=len(data)
nselected=len(sd)
ntrain=np.int(nselected*0.6)
nval=np.int(nselected*0.3)
print 'total input:', ndata, 'total selected:', nselected, 'selection efficiency:', np.divide(nselected,np.float(ndata))
# test first on the training set
sd_test_train = sd.head(ntrain+nval)
sd_train = sd_test_train.head(ntrain)
sd_test = sd_test_train.tail(nval)
print 'train on:',len(sd_train), 'testing on:',len(sd_test)
# Out:
# total input: 3050 total selected: 3038 selection efficiency: 0.99606557377
# train on: 1822 testing on: 911

# %%
sd_train[['t','Vfil','Vsup','sumV','Vmes','Vbb','Vch','Sa','Z','rSaVmes','rVbbVmes','rVchVmes','Vangover']].corr()
# Out:
#                  t      Vfil      Vsup      sumV      Vmes       Vbb  \
# t         1.000000  0.731170  0.757996  0.985809  0.696076  0.652653
# Vfil      0.731170  1.000000  0.113160  0.830461  0.962030  0.684058
# Vsup      0.757996  0.113160  1.000000  0.647473  0.100064  0.263596
# sumV      0.985809  0.830461  0.647473  1.000000  0.793995  0.672475
# Vmes      0.696076  0.962030  0.100064  0.793995  1.000000  0.696310
# Vbb       0.652653  0.684058  0.263596  0.672475  0.696310  1.000000
# Vch       0.666812  0.683538  0.279585  0.681041  0.683988  0.918530
# Sa        0.559169  0.600305  0.191505  0.567816  0.599424  0.792680
# Z         0.401319  0.450621  0.117129  0.411304  0.458004  0.594044
# rSaVmes  -0.185031 -0.269297 -0.018245 -0.216784 -0.270555 -0.123221
# rVbbVmes  0.007033 -0.080810  0.072667 -0.021240 -0.083200  0.268548
# rVchVmes  0.030843 -0.085153  0.101885 -0.008189 -0.090378  0.301817
# Vangover  0.462097  0.264528  0.392042  0.422706  0.265489  0.530236
#
#                Vch        Sa         Z   rSaVmes  rVbbVmes  rVchVmes  Vangover
# t         0.666812  0.559169  0.401319 -0.185031  0.007033  0.030843  0.462097
# Vfil      0.683538  0.600305  0.450621 -0.269297 -0.080810 -0.085153  0.264528
# Vsup      0.279585  0.191505  0.117129 -0.018245  0.072667  0.101885  0.392042
# sumV      0.681041  0.567816  0.411304 -0.216784 -0.021240 -0.008189  0.422706
# Vmes      0.683988  0.599424  0.458004 -0.270555 -0.083200 -0.090378  0.265489
# Vbb       0.918530  0.792680  0.594044 -0.123221  0.268548  0.301817  0.530236
# Vch       1.000000  0.863465  0.544688 -0.114844  0.177089  0.283573  0.536702
# Sa        0.863465  1.000000  0.504484 -0.031730  0.081687  0.187540  0.502332
# Z         0.544688  0.504484  1.000000 -0.179573  0.157062  0.167578  0.402033
# rSaVmes  -0.114844 -0.031730 -0.179573  1.000000  0.441234  0.557743 -0.013461
# rVbbVmes  0.177089  0.081687  0.157062  0.441234  1.000000  0.871745  0.126944
# rVchVmes  0.283573  0.187540  0.167578  0.557743  0.871745  1.000000  0.186679
# Vangover  0.536702  0.502332  0.402033 -0.013461  0.126944  0.186679  1.000000

# %% [markdown]
# ## Train

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
axes.scatter(sd_train.Vmes,sd_train.t/60, color='red',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
plt.xlabel('Extracted Volume (cm^3)')
plt.ylabel('Build Time (hours)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('Build Time (hours)', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t.png')

# %% [markdown]
# ## Overhang

# %%
labels=(sd.Vsup<0.1)
len(labels)
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
h1=plt.hist(sd_train.Vangover[labels],20,(0,10),color='red',alpha=0.5,label='has support material', histtype='step', stacked=False, fill=False,linewidth=5)
h2=plt.hist(sd_train.Vangover[~labels],20,(0,10),color='blue',alpha=0.5,label='no support material', histtype='step', stacked=False, fill=False, linewidth=5)
#plt.legend(loc='upper right')
plt.yscale('log')
plt.ylabel('# of Entries')
plt.xlabel('Volume Below Overhang (cm^3)')
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
plt.savefig(outdir+'/Vangover_sup0_vs_sup1.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vmes/sd_train.Vfil<1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vmes/sd_train.Vfil>1.1)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='black',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil.png')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
cut=(sd_train.Vsup<10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='red',marker='o',alpha=0.2)
cut=(sd_train.Vsup>10)
axes.scatter(sd_train.Vmes[cut],sd_train.t[cut]/60, color='blue',marker='o',alpha=0.2)
plt.xlim(1,1000)
plt.ylim(ymin=0,ymax=15000./60)    
axes.xaxis.set_tick_params(labelsize=20)
axes.yaxis.set_tick_params(labelsize=20)
axes.set_xlabel('Volume (cm^3)', fontsize=20)
axes.set_ylabel('# of Entries', fontsize=20)
fig.savefig(outdir+'/'+'Vmes_vs_t_cutVmesvsVfil_cutVsup.png')

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_basic = tdr(sd_train[['Vmes','Vch','Vbb','Sa','X','Z']].as_matrix(),sd_train['t'].as_matrix(),'forest',"TrainData_basic6var")
lregtrain_basic.transform()
lregtrain_basic.fit()
lregtrain_basic.predict()
lregtrain_basic.PlotPerformance(1,1000,'log',False)
lregtrain_basic.export_model()
# Out:
# Regression TrainData_basic6var_forest --- 1822 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.89711142  0.04242783  0.00760753  0.01034564  0.0128638   0.02964378]
# residual standard error (rse): 1676.03706036 residual mean_absolute_error: 276.155033846 residual mad 32.74875 276.155033846 <y>:  1116.30731797
# ratio (err):  0.247382624302
# R^2 score:  0.5714898734

# %%
import TDPPredictor
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
lregtrain_ols = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'ols',"TrainData_6var")
lregtrain_ols.transform()
lregtrain_ols.fit()
lregtrain_ols.predict()
lregtrain_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_ols --- 1822 entries
# coeffecients:
# 1116.30731797
# [ 1285.32050173   800.12988407    15.67232833  -288.49016609   -97.20751646
#    588.15964116]
# residual standard error (rse): 1639.99447573 residual mean_absolute_error: 408.231465479 residual mad 122.034399174 408.231465479 <y>:  1116.30731797
# ratio (err):  0.365698100254
# R^2 score:  0.589721626622

# %%
lregtrain = tdr(sd_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_train['t'].as_matrix(),'forest',"TrainData_6var")
lregtrain.transform()
lregtrain.fit()
lregtrain.predict()
lregtrain.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TrainData_6var_forest --- 1822 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88316559  0.03909996  0.00445656  0.01367715  0.02607413  0.03352661]
# residual standard error (rse): 1656.57203279 residual mean_absolute_error: 270.211095865 residual mad 29.10125 270.211095865 <y>:  1116.30731797
# ratio (err):  0.242057981271
# R^2 score:  0.58138527109

# %% [markdown]
# ## Test

# %%
lregtest_ols = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'ols',"TestData_6var")
lregtest_ols.scaler = lregtrain_basic.scaler
lregtest_ols.regr = lregtrain_basic.regr
lregtest_ols.transform()
lregtest_ols.predict()
lregtest_ols.PlotPerformance(1,1000,'log',False)
# Out:
# Regression TestData_6var_ols --- 911 entries
# residual standard error (rse): 848.479642319 residual mean_absolute_error: 267.313437614 residual mad 52.7783333333 267.313437614 <y>:  975.963757775
# ratio (err):  0.273896889597
# R^2 score:  0.792519970469

# %%
lregtest = tdr(sd_test[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix(),sd_test['t'].as_matrix(),'forest',"TestData_6var")
lregtest.scaler = lregtrain.scaler
lregtest.regr = lregtrain.regr
lregtest.transform()
lregtest.predict()
lregtest.PlotPerformance(0.5,1000,'log',False)
# Out:
# Regression TestData_6var_forest --- 911 entries
# residual standard error (rse): 824.706310939 residual mean_absolute_error: 234.309907611 residual mad 40.9875 234.309907611 <y>:  975.963757775
# ratio (err):  0.240080541664
# R^2 score:  0.803983746742

# %% [markdown]
# ## Cross-Validation

# %%
reload(TDPPredictor)
from TDPPredictor import TDPRegressor as tdr
from TDPPredictor import TDPClassifier as tdc

from sklearn.model_selection import KFold
kf = KFold(n_splits=8)
print kf.get_n_splits(lregtrain.X)
print(kf)
# Out:
# 8
# KFold(n_splits=8, random_state=None, shuffle=False)

# %%
len(sd_test_train)
X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','Vangover']].as_matrix()
#X_cv = sd_test_train[['Vmes','Vch','Vbb','Sa','Z','X']].as_matrix()
y_cv = sd_test_train['t'].as_matrix()

ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

for train_index, test_index in kf.split(X_cv):
    print '================================ Fold',ct
    #print("TRAIN:", train_index, "TEST:", test_index)


    # first train combined dataset
    X_all_cv_train, X_all_cv_test = X_cv[train_index], X_cv[test_index]
    y_all_cv_train, y_all_cv_test = y_cv[train_index], y_cv[test_index]
    
    regr_cv_train_all = tdr(X_all_cv_train,y_all_cv_train,'forest','cv_train_all_f%d'%ct)
    regr_cv_train_all.transform()
    regr_cv_train_all.fit()

    regr_cv_test_all = tdr(X_all_cv_test,y_all_cv_test,'forest','cv_test_all_f%d'%ct)
    regr_cv_test_all.scaler = regr_cv_train_all.scaler
    regr_cv_test_all.regr = regr_cv_train_all.regr
    regr_cv_test_all.transform()
    regr_cv_test_all.predict()
    regr_cv_test_all.PlotPerformance(0.5,1000,'log')
    err_all.append(regr_cv_test_all.frac_ame)
    r2_all.append(regr_cv_test_all.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# Regression cv_train_all_f0_forest --- 2391 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.86414295  0.03404941  0.02120661  0.03019388  0.01187758  0.03852958]
# Regression cv_test_all_f0_forest --- 342 entries
# residual standard error (rse): 686.805403634 residual mean_absolute_error: 214.449444444 residual mad 40.2158333333 214.449444444 <y>:  1012.14429825
# ratio (err):  0.211876354801
# R^2 score:  0.819963821367
# ================================ Fold 1
# Regression cv_train_all_f1_forest --- 2391 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88888687  0.03296723  0.0103303   0.02645876  0.01370665  0.02765019]
# Regression cv_test_all_f1_forest --- 342 entries
# residual standard error (rse): 2216.79724241 residual mean_absolute_error: 322.704505361 residual mad 40.6345833333 322.704505361 <y>:  1173.52153996
# ratio (err):  0.274988139861
# R^2 score:  0.457694617242
# ================================ Fold 2
# Regression cv_train_all_f2_forest --- 2391 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88383942  0.01428481  0.02027578  0.02782549  0.00794656  0.04582795]
# Regression cv_test_all_f2_forest --- 342 entries
# residual standard error (rse): 1042.27754744 residual mean_absolute_error: 282.359144737 residual mad 43.7195833333 282.359144737 <y>:  1046.07577973
# ratio (err):  0.269922265871
# R^2 score:  0.714358186325
# ================================ Fold 3
# Regression cv_train_all_f3_forest --- 2391 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.89007521  0.02586168  0.01984811  0.01419395  0.00511103  0.04491003]
# Regression cv_test_all_f3_forest --- 342 entries
# residual standard error (rse): 2336.97139221 residual mean_absolute_error: 327.979169103 residual mad 50.4575 327.979169103 <y>:  1010.33157895
# ratio (err):  0.324625277421
# R^2 score:  0.318875078124
# ================================ Fold 4
# Regression cv_train_all_f4_forest --- 2391 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.87551563  0.01238889  0.01372741  0.03149768  0.01441444  0.05245595]
# Regression cv_test_all_f4_forest --- 342 entries
# residual standard error (rse): 2055.2059146 residual mean_absolute_error: 444.663345517 residual mad 38.1395833333 444.663345517 <y>:  1442.77066277
# ratio (err):  0.308200989243
# R^2 score:  0.615328646359
# ================================ Fold 5
# Regression cv_train_all_f5_forest --- 2392 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.9031909   0.02430448  0.00744881  0.00727429  0.01183773  0.04594379]
# Regression cv_test_all_f5_forest --- 341 entries
# residual standard error (rse): 1240.00995608 residual mean_absolute_error: 338.30948436 residual mad 41.5541666667 338.30948436 <y>:  1024.07223851
# ratio (err):  0.330357050642
# R^2 score:  0.649434689497
# ================================ Fold 6
# Regression cv_train_all_f6_forest --- 2392 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.90033866  0.01739518  0.00599751  0.0137069   0.01417692  0.04838483]
# Regression cv_test_all_f6_forest --- 341 entries
# residual standard error (rse): 606.831167213 residual mean_absolute_error: 193.53659824 residual mad 37.4933333333 193.53659824 <y>:  1002.95024438
# ratio (err):  0.192967297555
# R^2 score:  0.895538908738
# ================================ Fold 7
# Regression cv_train_all_f7_forest --- 2392 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.89525362  0.01885091  0.01013319  0.01823331  0.0142581   0.04327088]
# Regression cv_test_all_f7_forest --- 341 entries
# residual standard error (rse): 409.982937087 residual mean_absolute_error: 165.637810362 residual mad 46.6766666667 165.637810362 <y>:  843.353812317
# ratio (err):  0.196403701439
# R^2 score:  0.896246064671

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_all)
h=plt.hist(err_all,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_all)
h=plt.hist(r2_all,20,(0,1))
# Out:
# 0.263667634604
# 0.67093000154

# %%
ct=0
err_all=[]
r2_all=[]
err_sup0=[]
r2_sup0=[]
err_sup1=[]
r2_sup1=[]

#X_clf_cv = sd_test_train[['Vangover','diffVchVmes','Sa']].as_matrix()
X_clf_cv = sd_test_train[['Vangover','diffVchVmes']].as_matrix()
#X_clf_cv = sd_test_train[['Vsup']].as_matrix()
y_clf_cv = ((sd_test_train['Vsup']>0.1).as_matrix()).astype(np.float)

for train_index, test_index in kf.split(X_clf_cv):
    print '================================ Fold',ct
    # now train classifier
    X_clf_train, X_clf_test = X_clf_cv[train_index], X_clf_cv[test_index]
    y_clf_train, y_clf_test = y_clf_cv[train_index], y_clf_cv[test_index]
    print len(X_clf_train),len(y_clf_train),len(X_clf_test),len(y_clf_test)
    clf_cv_train =tdc(X_clf_train,y_clf_train)
    clf_cv_train.transform()
    clf_cv_train.fit()
    clf_cv_train.predict()
    # now test classifier
    clf_cv_test =tdc(X_clf_test,y_clf_test)
    clf_cv_test.clf = clf_cv_train.clf
    clf_cv_test.scaler = clf_cv_train.scaler
    clf_cv_test.transform()
    clf_cv_test.predict()
    
    # regression
    X_train, X_test = X_cv[train_index], X_cv[test_index]
    y_train, y_test = y_cv[train_index], y_cv[test_index]
    # train and test for no support volume
    regr_cv_train_sup0 = tdr(X_train[clf_cv_train.yhat==0],y_train[clf_cv_train.yhat==0],'forest','cv_train_sup0_f%d'%ct)
    regr_cv_train_sup0.transform()
    regr_cv_train_sup0.fit()

    regr_cv_test_sup0 = tdr(X_test[clf_cv_test.yhat==0],y_test[clf_cv_test.yhat==0],'forest','cv_test_sup0_f%d'%ct)
    if len(regr_cv_test_sup0.X) < 10:
        continue
    regr_cv_test_sup0.scaler = regr_cv_train_sup0.scaler
    regr_cv_test_sup0.regr = regr_cv_train_sup0.regr
    regr_cv_test_sup0.transform()
    regr_cv_test_sup0.predict()
    #regr_cv_test_sup0.PlotPerformance(0.5,1000,'log')
    err_sup0.append(regr_cv_test_sup0.frac_ame)
    r2_sup0.append(regr_cv_test_sup0.R2)

    #now train and test regression for with support volume
    regr_cv_train_sup1 = tdr(X_train[clf_cv_train.yhat==1],y_train[clf_cv_train.yhat==1],'forest','cv_train_sup1_f%d'%ct)
    regr_cv_train_sup1.transform()
    regr_cv_train_sup1.fit()

    regr_cv_test_sup1 = tdr(X_test[clf_cv_test.yhat==1],y_test[clf_cv_test.yhat==1],'forest','cv_test_sup1_f%d'%ct)
    if len(regr_cv_test_sup1.X) < 10:
        continue
    regr_cv_test_sup1.scaler = regr_cv_train_sup1.scaler
    regr_cv_test_sup1.regr = regr_cv_train_sup1.regr
    regr_cv_test_sup1.transform()
    regr_cv_test_sup1.predict()
    #regr_cv_test_sup1.PlotPerformance(0.5,1000,'log')
    err_sup1.append(regr_cv_test_sup1.frac_ame)
    r2_sup1.append(regr_cv_test_sup1.R2)

    ct=ct+1
# Out:
# ================================ Fold 0
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.26204054]
# [[ 6.97197114  0.26296586]]
# [[836 164]
#  [403 988]]
# Classifier train --- 342 entries
# [[115  27]
#  [ 56 144]]
# Regression cv_train_sup0_f0_forest --- 1239 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.91120029  0.05027642  0.00591737  0.01020188  0.0163182   0.00608585]
# Regression cv_test_sup0_f0_forest --- 171 entries
# residual standard error (rse): 725.272839988 residual mean_absolute_error: 142.709269006 residual mad 21.8658333333 142.709269006 <y>:  533.211403509
# ratio (err):  0.267641067064
# R^2 score:  0.459733200432
# Regression cv_train_sup1_f0_forest --- 1152 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.8499349   0.02664524  0.03113922  0.02587765  0.00656712  0.05983588]
# Regression cv_test_sup1_f0_forest --- 171 entries
# residual standard error (rse): 913.88837767 residual mean_absolute_error: 332.929522417 residual mad 74.4975 332.929522417 <y>:  1491.07719298
# ratio (err):  0.22328121172
# R^2 score:  0.780656613477
# ================================ Fold 1
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.18449071]
# [[ 6.90815864  0.17536349]]
# [[859 152]
#  [422 958]]
# Classifier train --- 342 entries
# [[117  14]
#  [ 69 142]]
# Regression cv_train_sup0_f1_forest --- 1281 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.89107359  0.08432015  0.00776238  0.01655335  0.01349058 -0.01320005]
# Regression cv_test_sup0_f1_forest --- 186 entries
# residual standard error (rse): 261.546892465 residual mean_absolute_error: 89.5897849462 residual mad 20.5879166667 89.5897849462 <y>:  429.230197133
# ratio (err):  0.208721999395
# R^2 score:  0.626581610673
# Regression cv_train_sup1_f1_forest --- 1110 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.89253375  0.03128979  0.01318821  0.01937733  0.01327502  0.03033591]
# Regression cv_test_sup1_f1_forest --- 156 entries
# residual standard error (rse): 3526.74485565 residual mean_absolute_error: 678.170528846 residual mad 79.9541666667 678.170528846 <y>:  2060.94583333
# ratio (err):  0.329057910149
# R^2 score:  0.316579093572
# ================================ Fold 2
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.28357466]
# [[ 7.00277088  0.21143913]]
# [[ 825  168]
#  [ 382 1016]]
# Classifier train --- 342 entries
# [[126  23]
#  [ 54 139]]
# Regression cv_train_sup0_f2_forest --- 1207 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.86598997  0.08578047  0.00880275  0.02053242  0.01076192  0.00813247]
# Regression cv_test_sup0_f2_forest --- 180 entries
# residual standard error (rse): 403.379188661 residual mean_absolute_error: 132.411027778 residual mad 24.8308333333 132.411027778 <y>:  488.078240741
# ratio (err):  0.271290577463
# R^2 score:  0.565606163578
# Regression cv_train_sup1_f2_forest --- 1184 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.86592866  0.04418381  0.00557213  0.02733296  0.01215506  0.04482737]
# Regression cv_test_sup1_f2_forest --- 162 entries
# residual standard error (rse): 1444.74265838 residual mean_absolute_error: 428.777443416 residual mad 76.41 428.777443416 <y>:  1666.07304527
# ratio (err):  0.257358130025
# R^2 score:  0.696719591748
# ================================ Fold 3
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.40646322]
# [[ 7.75632504  0.23672111]]
# [[ 833  154]
#  [ 390 1014]]
# Classifier train --- 342 entries
# [[118  37]
#  [ 50 137]]
# Regression cv_train_sup0_f3_forest --- 1223 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88438723  0.06284072  0.01281898  0.02542624  0.0079281   0.00659872]
# Regression cv_test_sup0_f3_forest --- 168 entries
# residual standard error (rse): 438.525719704 residual mean_absolute_error: 110.599434524 residual mad 26.19375 110.599434524 <y>:  475.457539683
# ratio (err):  0.232616848599
# R^2 score:  0.575553873292
# Regression cv_train_sup1_f3_forest --- 1168 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.8835062   0.0227693   0.01471505  0.0100649   0.00844469  0.06049986]
# Regression cv_test_sup1_f3_forest --- 174 entries
# residual standard error (rse): 3264.40749064 residual mean_absolute_error: 543.719319923 residual mad 97.46625 543.719319923 <y>:  1526.76168582
# ratio (err):  0.356125861012
# R^2 score:  0.278984525456
# ================================ Fold 4
# 2391 2391 342 342
# Classifier train --- 2391 entries
# [ 1.13629876]
# [[ 6.44519776  0.19008794]]
# [[ 827  171]
#  [ 386 1007]]
# Classifier train --- 342 entries
# [[119  25]
#  [ 40 158]]
# Regression cv_train_sup0_f4_forest --- 1213 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88518167  0.06423099  0.00865309  0.01718036  0.01610516  0.00864873]
# Regression cv_test_sup0_f4_forest --- 159 entries
# residual standard error (rse): 988.247987824 residual mean_absolute_error: 148.559103774 residual mad 17.7591666667 148.559103774 <y>:  473.125366876
# ratio (err):  0.31399522024
# R^2 score:  0.417505585729
# Regression cv_train_sup1_f4_forest --- 1178 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.85367179  0.0253814   0.02010733  0.03321554  0.01579469  0.05182925]
# Regression cv_test_sup1_f4_forest --- 183 entries
# residual standard error (rse): 2812.85475113 residual mean_absolute_error: 750.058155738 residual mad 83.8808333333 750.058155738 <y>:  2285.24936248
# ratio (err):  0.3282172038
# R^2 score:  0.548842368212
# ================================ Fold 5
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.32102712]
# [[ 7.54004714  0.13931427]]
# [[859 140]
#  [410 983]]
# Classifier train --- 341 entries
# [[118  25]
#  [ 62 136]]
# Regression cv_train_sup0_f5_forest --- 1269 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.87523516  0.07157383  0.00462117  0.021129    0.01938756  0.00805327]
# Regression cv_test_sup0_f5_forest --- 180 entries
# residual standard error (rse): 369.406180929 residual mean_absolute_error: 105.593064815 residual mad 24.0808333333 105.593064815 <y>:  457.114444444
# ratio (err):  0.230999186524
# R^2 score:  0.558349983951
# Regression cv_train_sup1_f5_forest --- 1123 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.8871192   0.02796475  0.02544828  0.00743083  0.00834515  0.04369179]
# Regression cv_test_sup1_f5_forest --- 161 entries
# residual standard error (rse): 1694.06455783 residual mean_absolute_error: 586.300144928 residual mad 108.458333333 586.300144928 <y>:  1657.93809524
# ratio (err):  0.353632108829
# R^2 score:  0.649302269794
# ================================ Fold 6
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.26599498]
# [[ 5.381229    0.18699238]]
# [[828 160]
#  [407 997]]
# Classifier train --- 341 entries
# [[135  19]
#  [ 54 133]]
# Regression cv_train_sup0_f6_forest --- 1235 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.85400248  0.09991328  0.00711235  0.01832532  0.00897621  0.01167036]
# Regression cv_test_sup0_f6_forest --- 189 entries
# residual standard error (rse): 401.393137903 residual mean_absolute_error: 93.5282495591 residual mad 20.2958333333 93.5282495591 <y>:  554.838095238
# ratio (err):  0.16856854344
# R^2 score:  0.827503908274
# Regression cv_train_sup1_f6_forest --- 1157 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.85779247  0.01592739  0.0195499   0.02345873  0.0174691   0.06580242]
# Regression cv_test_sup1_f6_forest --- 152 entries
# residual standard error (rse): 830.661763124 residual mean_absolute_error: 326.301047149 residual mad 60.2008333333 326.301047149 <y>:  1560.14232456
# ratio (err):  0.209148256548
# R^2 score:  0.888474591024
# ================================ Fold 7
# 2392 2392 341 341
# Classifier train --- 2392 entries
# [ 1.14330159]
# [[ 6.60838286  0.1957845 ]]
# [[867 151]
#  [443 931]]
# Classifier train --- 341 entries
# [[113  11]
#  [ 72 145]]
# Regression cv_train_sup0_f7_forest --- 1310 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.83760307  0.12426468  0.00493247  0.01516594  0.01069793  0.00733591]
# Regression cv_test_sup0_f7_forest --- 185 entries
# residual standard error (rse): 281.171156626 residual mean_absolute_error: 98.5787837838 residual mad 28.5258333333 98.5787837838 <y>:  426.718288288
# ratio (err):  0.23101607428
# R^2 score:  0.517218347751
# Regression cv_train_sup1_f7_forest --- 1082 entries
# random forest nfeatures: 6
# random forest feature importances
# [ 0.88067033  0.00938503  0.01836946  0.01941166  0.01479413  0.05736939]
# Regression cv_test_sup1_f7_forest --- 156 entries
# residual standard error (rse): 544.140585914 residual mean_absolute_error: 249.081923077 residual mad 90.2195833333 249.081923077 <y>:  1337.44081197
# ratio (err):  0.186237716726
# R^2 score:  0.897797458185

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup0)
h=plt.hist(err_sup0,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup0)
h=plt.hist(r2_sup0,20,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(err_sup1)
h=plt.hist(err_sup1,40,(0,1))
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(7,7))
print np.mean(r2_sup1)
h=plt.hist(r2_sup1,20,(0,1))
# Out:
# 0.240606189626
# 0.56850658421
# 0.280382299851
# 0.632169563934
